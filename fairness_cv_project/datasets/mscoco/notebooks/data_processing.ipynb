# %%
import json
import statistics
import random
import copy
import string

import pandas as pd
import numpy as np

# %%
#set random seed for reproducibility
random.seed(1)

# %%
captions_filename = "annotations/captions_train2014.json"

annotation = json.load(open(captions_filename))

images = annotation["images"]

captions = annotation["annotations"]

images[0]
# Out:
# {'license': 5,
#  'file_name': 'COCO_train2014_000000057870.jpg',
#  'coco_url': 'http://images.cocodataset.org/train2014/COCO_train2014_000000057870.jpg',
#  'height': 480,
#  'width': 640,
#  'date_captured': '2013-11-14 16:28:13',
#  'flickr_url': 'http://farm4.staticflickr.com/3153/2970773875_164f0c0b83_z.jpg',
#  'id': 57870}

# %%
# Create dictionary of images with image id as key and metadata as value
images_dict = {}
for image in images:
    images_dict[image["id"]] = {"file_name": image["file_name"], "captions": []}
list(images_dict.items())[0:5]
# Out:
# [(57870, {'file_name': 'COCO_train2014_000000057870.jpg', 'captions': []}),
#  (384029, {'file_name': 'COCO_train2014_000000384029.jpg', 'captions': []}),
#  (222016, {'file_name': 'COCO_train2014_000000222016.jpg', 'captions': []}),
#  (520950, {'file_name': 'COCO_train2014_000000520950.jpg', 'captions': []}),
#  (69675, {'file_name': 'COCO_train2014_000000069675.jpg', 'captions': []})]

# %%
captions[0:5]
# Out:
# [{'image_id': 318556,
#   'id': 48,
#   'caption': 'A very clean and well decorated empty bathroom'},
#  {'image_id': 116100,
#   'id': 67,
#   'caption': 'A panoramic view of a kitchen and all of its appliances.'},
#  {'image_id': 318556,
#   'id': 126,
#   'caption': 'A blue and white bathroom with butterfly themed wall tiles.'},
#  {'image_id': 116100,
#   'id': 148,
#   'caption': 'A panoramic photo of a kitchen and dining room'},
#  {'image_id': 379340,
#   'id': 173,
#   'caption': 'A graffiti-ed stop sign across the street from a red car '}]

# %%
#define gender labels
male_labels = ["man", "male"]
female_labels = ["woman", "female"]

# %%
# Associate captions with images
for caption in captions:
    image_id = caption["image_id"]
    caption_text = caption["caption"]
    if not (caption_text in images_dict[image_id]["captions"]):
        images_dict[image_id]["captions"].append(caption_text.lower())

list(images_dict.items())[0:5]
# Out:
# [(57870,
#   {'file_name': 'COCO_train2014_000000057870.jpg',
#    'captions': ['a restaurant has modern wooden tables and chairs.',
#     'a long restaurant table with rattan rounded back chairs.',
#     'a long table with a plant on top of it surrounded with wooden chairs ',
#     'a long table with a flower arrangement in the middle for meetings',
#     'a table is adorned with wooden chairs with blue accents.']}),
#  (384029,
#   {'file_name': 'COCO_train2014_000000384029.jpg',
#    'captions': ['a man preparing desserts in a kitchen covered in frosting.',
#     'a chef is preparing and decorating many small pastries.',
#     'a baker prepares various types of baked goods.',
#     'a close up of a person grabbing a pastry in a container',
#     'close up of a hand touching various pastries.']}),
#  (222016,
#   {'file_name': 'COCO_train2014_000000222016.jpg',
#    'captions': ['a big red telephone booth that a man is standing in',
#     'a person standing inside of a phone booth ',
#     'this is an image of a man in a phone booth.',
#     'a man is standing in a red phone booth.',
#     'a man using a phone in a phone booth.']}),
#  (520950,
#   {'file_name': 'COCO_train2014_000000520950.jpg',
#    'captions': ['the kitchen is full of spices on the rack',
#     'a kitchen with counter, oven and other accessories.',
#     'a small kitchen that utilizes all of its space. ',
#     'this small kitchen has pots, pans and spices on display',
#     'a very small kitchen with a stove and a shelf of pots ']}),
#  (69675,
#   {'file_name': 'COCO_train2014_000000069675.jpg',
#    'captions': ['a child and woman are cooking in the kitchen.',
#     "a woman glances at a young girl's cooking on the stovetop",
#     'a young girl and a woman preparing food in a kitchen.',
#     'a young person and an older person in a kitchen',
#     'two women cooking on stove in a kitchen together.']})]

# %%
def is_whole_word_in_text(word, text):
    #replace punctuation with spaces
    for p in string.punctuation:
        text = text.replace(p, " ")
    words = text.split()
    return word in words

print(is_whole_word_in_text("man", "a woman is eating a sandwich"))
print(is_whole_word_in_text("man", "a man."))
# Out:
# False
# True

# %%
len(images_dict.items())
# Out:
# 82783

# %%
# Classify gender of images, removing ones that don't have a clear gender
images_dict_items = list(images_dict.items())
deleted_image_ids = []
for image_id, image_data in images_dict_items:
    male = False
    female = False
    for caption in image_data["captions"]:
        if any(is_whole_word_in_text(label, caption) for label in male_labels):
            male = True
        if any(is_whole_word_in_text(label, caption) for label in female_labels):
            female = True
    if male ^ female:
        if male:
            images_dict[image_id]["gender"] = "male"
        else:
            images_dict[image_id]["gender"] = "female"
    else:
        deleted_image_ids.append(image_id)
        del images_dict[image_id]

len(images_dict.items())
# Out:
# 23279

# %%
len(deleted_image_ids)
# Out:
# 59504

# %%
list(images_dict.items())[0:5]
# Out:
# [(384029,
#   {'file_name': 'COCO_train2014_000000384029.jpg',
#    'captions': ['a man preparing desserts in a kitchen covered in frosting.',
#     'a chef is preparing and decorating many small pastries.',
#     'a baker prepares various types of baked goods.',
#     'a close up of a person grabbing a pastry in a container',
#     'close up of a hand touching various pastries.'],
#    'gender': 'male'}),
#  (222016,
#   {'file_name': 'COCO_train2014_000000222016.jpg',
#    'captions': ['a big red telephone booth that a man is standing in',
#     'a person standing inside of a phone booth ',
#     'this is an image of a man in a phone booth.',
#     'a man is standing in a red phone booth.',
#     'a man using a phone in a phone booth.'],
#    'gender': 'male'}),
#  (69675,
#   {'file_name': 'COCO_train2014_000000069675.jpg',
#    'captions': ['a child and woman are cooking in the kitchen.',
#     "a woman glances at a young girl's cooking on the stovetop",
#     'a young girl and a woman preparing food in a kitchen.',
#     'a young person and an older person in a kitchen',
#     'two women cooking on stove in a kitchen together.'],
#    'gender': 'female'}),
#  (547471,
#   {'file_name': 'COCO_train2014_000000547471.jpg',
#    'captions': ['a black and white image of a man in a suit wearing glasses walking through a door.',
#     'a nicely dressed man in a door way.',
#     'a man in glasses walks through an open door. ',
#     ' a man smiling and walking through a doorway.',
#     'a black and white photo of a man in suit and tie.'],
#    'gender': 'male'}),
#  (90570,
#   {'file_name': 'COCO_train2014_000000090570.jpg',
#    'captions': ['two people in a food truck, one looking at an order.',
#     'a man in a beanie and glasses leans over a counter.',
#     'a man in a food cart looking down at a piece of paper.',
#     'a man with a beard and a blue shirt is making some food',
#     'a person working behind the counter of a food truck.'],
#    'gender': 'male'})]

# %%
for image_id, image_data in images_dict.items():
    del image_data["captions"]

list(images_dict.items())[0:5]
# Out:
# [(384029, {'file_name': 'COCO_train2014_000000384029.jpg', 'gender': 'male'}),
#  (222016, {'file_name': 'COCO_train2014_000000222016.jpg', 'gender': 'male'}),
#  (69675, {'file_name': 'COCO_train2014_000000069675.jpg', 'gender': 'female'}),
#  (547471, {'file_name': 'COCO_train2014_000000547471.jpg', 'gender': 'male'}),
#  (90570, {'file_name': 'COCO_train2014_000000090570.jpg', 'gender': 'male'})]

# %% [markdown]
# # Combing targets

# %%
instaces_filename = "annotations/instances_train2014.json"

instance_annotations = json.load(open(instaces_filename))

cat_annotations_raw = instance_annotations["annotations"]

categories = instance_annotations["categories"]

# %%
categories[0:5]
# Out:
# [{'supercategory': 'person', 'id': 1, 'name': 'person'},
#  {'supercategory': 'vehicle', 'id': 2, 'name': 'bicycle'},
#  {'supercategory': 'vehicle', 'id': 3, 'name': 'car'},
#  {'supercategory': 'vehicle', 'id': 4, 'name': 'motorcycle'},
#  {'supercategory': 'vehicle', 'id': 5, 'name': 'airplane'}]

# %%
cat_annotations = []
for antn in cat_annotations_raw:
    new_antn = {"id": antn["id"], "image_id": antn["image_id"], "category_id": antn["category_id"]}
    cat_annotations.append(new_antn)

cat_annotations[0:5]
# Out:
# [{'id': 86, 'image_id': 480023, 'category_id': 58},
#  {'id': 89, 'image_id': 50518, 'category_id': 58},
#  {'id': 93, 'image_id': 142589, 'category_id': 58},
#  {'id': 113, 'image_id': 209263, 'category_id': 58},
#  {'id': 116, 'image_id': 15307, 'category_id': 58}]

# %%
# create a category dictionary
cat_dict = {}
for cat in categories:
    cat_dict[cat["id"]] = cat["name"]

# Associate categories with their names
for antn in cat_annotations:
    antn["category_name"] = cat_dict[antn["category_id"]]
    del antn["category_id"]

cat_annotations[0:5]
# Out:
# [{'id': 86, 'image_id': 480023, 'category_name': 'hot dog'},
#  {'id': 89, 'image_id': 50518, 'category_name': 'hot dog'},
#  {'id': 93, 'image_id': 142589, 'category_name': 'hot dog'},
#  {'id': 113, 'image_id': 209263, 'category_name': 'hot dog'},
#  {'id': 116, 'image_id': 15307, 'category_name': 'hot dog'}]

# %%
# Associate categories with images
for image_id, image_data in images_dict.items():
    image_data["targets"] = []

for antn in cat_annotations:
    image_id = antn["image_id"]
    category_name = antn["category_name"]
    if (image_id in images_dict):
        image_data = images_dict[image_id]
        if not (category_name in image_data["targets"]):
            image_data["targets"].append(category_name)

#remove images that do not include person targets
items = list(images_dict.items())
for image_id, image_data in items:
    if not ("person" in image_data["targets"]):
        del images_dict[image_id]

len(images_dict.items())
# Out:
# 23010

# %% [markdown]
# # Making final JSON format

# %%
target_img_dict = {}
for category in categories:
    category_name = category["name"]
    target_img_dict[category_name] = {}
    for image_id, image_data in images_dict.items():
        if category_name in image_data["targets"]:
            target_img_dict[category_name][image_id] = image_data.copy()
            target_img_dict[category_name][image_id]["target"] = category_name
            target_img_dict[category_name][image_id]["other_targets"] = list(filter(lambda x: x != category_name, image_data["targets"]))
            del target_img_dict[category_name][image_id]["targets"]

list(target_img_dict.items())[1]
# Out:
# ('bicycle',
#  {283524: {'file_name': 'COCO_train2014_000000283524.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['potted plant', 'cup', 'knife', 'bowl', 'person']},
#   530683: {'file_name': 'COCO_train2014_000000530683.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['dog',
#     'car',
#     'person',
#     'traffic light',
#     'bus',
#     'handbag']},
#   441488: {'file_name': 'COCO_train2014_000000441488.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'cell phone', 'bench']},
#   64897: {'file_name': 'COCO_train2014_000000064897.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard', 'backpack']},
#   481736: {'file_name': 'COCO_train2014_000000481736.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'surfboard', 'car']},
#   57745: {'file_name': 'COCO_train2014_000000057745.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['backpack', 'person', 'bench', 'handbag', 'kite']},
#   511231: {'file_name': 'COCO_train2014_000000511231.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'boat', 'traffic light', 'backpack', 'car']},
#   58403: {'file_name': 'COCO_train2014_000000058403.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['bottle',
#     'chair',
#     'dining table',
#     'person',
#     'spoon',
#     'cake',
#     'fork']},
#   460897: {'file_name': 'COCO_train2014_000000460897.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'motorcycle', 'person', 'truck']},
#   133113: {'file_name': 'COCO_train2014_000000133113.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['tie', 'car', 'person', 'book']},
#   298262: {'file_name': 'COCO_train2014_000000298262.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'umbrella', 'tie']},
#   415589: {'file_name': 'COCO_train2014_000000415589.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['kite', 'person', 'dog']},
#   114353: {'file_name': 'COCO_train2014_000000114353.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person']},
#   483781: {'file_name': 'COCO_train2014_000000483781.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'bus', 'person', 'umbrella', 'truck']},
#   6489: {'file_name': 'COCO_train2014_000000006489.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'backpack']},
#   440087: {'file_name': 'COCO_train2014_000000440087.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'umbrella', 'handbag']},
#   393896: {'file_name': 'COCO_train2014_000000393896.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'bus', 'person', 'truck', 'handbag']},
#   22056: {'file_name': 'COCO_train2014_000000022056.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['bus', 'person', 'clock', 'motorcycle']},
#   166621: {'file_name': 'COCO_train2014_000000166621.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'bus', 'person', 'truck', 'backpack']},
#   189706: {'file_name': 'COCO_train2014_000000189706.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard']},
#   311827: {'file_name': 'COCO_train2014_000000311827.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['couch',
#     'tv',
#     'cup',
#     'laptop',
#     'mouse',
#     'remote',
#     'person',
#     'bottle',
#     'potted plant',
#     'cell phone']},
#   397736: {'file_name': 'COCO_train2014_000000397736.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car',
#     'person',
#     'tennis racket',
#     'sports ball',
#     'backpack']},
#   502362: {'file_name': 'COCO_train2014_000000502362.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['boat', 'person']},
#   517049: {'file_name': 'COCO_train2014_000000517049.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['bottle',
#     'motorcycle',
#     'person',
#     'cup',
#     'donut',
#     'dining table',
#     'sandwich',
#     'chair']},
#   210431: {'file_name': 'COCO_train2014_000000210431.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['sports ball', 'person']},
#   304134: {'file_name': 'COCO_train2014_000000304134.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person', 'backpack', 'handbag']},
#   122551: {'file_name': 'COCO_train2014_000000122551.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'traffic light', 'backpack']},
#   182064: {'file_name': 'COCO_train2014_000000182064.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'bus', 'person', 'book', 'backpack']},
#   561177: {'file_name': 'COCO_train2014_000000561177.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'traffic light', 'person']},
#   30643: {'file_name': 'COCO_train2014_000000030643.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person', 'umbrella']},
#   251569: {'file_name': 'COCO_train2014_000000251569.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'umbrella', 'backpack']},
#   524420: {'file_name': 'COCO_train2014_000000524420.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['dog', 'car', 'person', 'backpack', 'handbag']},
#   178849: {'file_name': 'COCO_train2014_000000178849.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'umbrella', 'handbag']},
#   252994: {'file_name': 'COCO_train2014_000000252994.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard']},
#   297104: {'file_name': 'COCO_train2014_000000297104.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['chair',
#     'dining table',
#     'car',
#     'person',
#     'bottle',
#     'cup',
#     'fork',
#     'boat',
#     'umbrella',
#     'knife',
#     'handbag']},
#   230756: {'file_name': 'COCO_train2014_000000230756.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'bench', 'cell phone', 'handbag', 'bottle']},
#   333537: {'file_name': 'COCO_train2014_000000333537.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['bird',
#     'car',
#     'person',
#     'bench',
#     'traffic light',
#     'handbag']},
#   322391: {'file_name': 'COCO_train2014_000000322391.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['handbag', 'person']},
#   127134: {'file_name': 'COCO_train2014_000000127134.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['dog', 'car', 'motorcycle', 'person']},
#   52308: {'file_name': 'COCO_train2014_000000052308.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'umbrella']},
#   331082: {'file_name': 'COCO_train2014_000000331082.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'handbag', 'person']},
#   129108: {'file_name': 'COCO_train2014_000000129108.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['traffic light',
#     'person',
#     'car',
#     'train',
#     'bench',
#     'umbrella',
#     'handbag',
#     'suitcase']},
#   536827: {'file_name': 'COCO_train2014_000000536827.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'backpack', 'handbag', 'stop sign']},
#   452905: {'file_name': 'COCO_train2014_000000452905.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['bottle', 'person']},
#   208055: {'file_name': 'COCO_train2014_000000208055.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['tv',
#     'person',
#     'cup',
#     'spoon',
#     'chair',
#     'bench',
#     'dining table']},
#   386722: {'file_name': 'COCO_train2014_000000386722.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person']},
#   216150: {'file_name': 'COCO_train2014_000000216150.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'motorcycle', 'handbag', 'car', 'truck']},
#   505579: {'file_name': 'COCO_train2014_000000505579.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person']},
#   220894: {'file_name': 'COCO_train2014_000000220894.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle',
#     'traffic light',
#     'banana',
#     'handbag',
#     'person']},
#   497415: {'file_name': 'COCO_train2014_000000497415.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'truck', 'person']},
#   174601: {'file_name': 'COCO_train2014_000000174601.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person']},
#   579137: {'file_name': 'COCO_train2014_000000579137.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person']},
#   581061: {'file_name': 'COCO_train2014_000000581061.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car',
#     'bus',
#     'person',
#     'traffic light',
#     'backpack',
#     'fire hydrant',
#     'truck',
#     'stop sign']},
#   203462: {'file_name': 'COCO_train2014_000000203462.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['cow', 'motorcycle', 'person']},
#   51342: {'file_name': 'COCO_train2014_000000051342.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person',
#     'umbrella',
#     'traffic light',
#     'backpack',
#     'fire hydrant',
#     'cell phone']},
#   269588: {'file_name': 'COCO_train2014_000000269588.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'umbrella', 'cell phone', 'handbag']},
#   379172: {'file_name': 'COCO_train2014_000000379172.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'handbag', 'car', 'suitcase']},
#   238086: {'file_name': 'COCO_train2014_000000238086.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['banana', 'person']},
#   337262: {'file_name': 'COCO_train2014_000000337262.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car',
#     'bus',
#     'train',
#     'person',
#     'skateboard',
#     'traffic light']},
#   557496: {'file_name': 'COCO_train2014_000000557496.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['backpack', 'kite', 'person']},
#   80471: {'file_name': 'COCO_train2014_000000080471.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'clock', 'traffic light', 'backpack']},
#   534511: {'file_name': 'COCO_train2014_000000534511.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'cell phone']},
#   461996: {'file_name': 'COCO_train2014_000000461996.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'stop sign', 'cell phone', 'handbag']},
#   266244: {'file_name': 'COCO_train2014_000000266244.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person', 'umbrella', 'handbag']},
#   385972: {'file_name': 'COCO_train2014_000000385972.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'traffic light', 'backpack', 'truck']},
#   373373: {'file_name': 'COCO_train2014_000000373373.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['train', 'person', 'handbag']},
#   89207: {'file_name': 'COCO_train2014_000000089207.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'umbrella', 'handbag']},
#   102405: {'file_name': 'COCO_train2014_000000102405.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['umbrella', 'car', 'person', 'handbag']},
#   314778: {'file_name': 'COCO_train2014_000000314778.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard']},
#   506026: {'file_name': 'COCO_train2014_000000506026.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['cell phone', 'person', 'backpack']},
#   364833: {'file_name': 'COCO_train2014_000000364833.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person', 'refrigerator']},
#   187473: {'file_name': 'COCO_train2014_000000187473.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'car', 'truck', 'traffic light']},
#   127786: {'file_name': 'COCO_train2014_000000127786.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car',
#     'bus',
#     'person',
#     'truck',
#     'handbag',
#     'cell phone',
#     'traffic light']},
#   24380: {'file_name': 'COCO_train2014_000000024380.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'bus', 'person', 'backpack', 'handbag']},
#   558372: {'file_name': 'COCO_train2014_000000558372.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['dining table',
#     'car',
#     'person',
#     'parking meter',
#     'backpack',
#     'traffic light',
#     'handbag',
#     'chair']},
#   233991: {'file_name': 'COCO_train2014_000000233991.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'bench', 'skateboard']},
#   265781: {'file_name': 'COCO_train2014_000000265781.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person',
#     'car',
#     'bottle',
#     'truck',
#     'cell phone',
#     'donut']},
#   79912: {'file_name': 'COCO_train2014_000000079912.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['dog', 'person', 'bench', 'handbag']},
#   196510: {'file_name': 'COCO_train2014_000000196510.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'backpack']},
#   33572: {'file_name': 'COCO_train2014_000000033572.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'motorcycle']},
#   451550: {'file_name': 'COCO_train2014_000000451550.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['train',
#     'traffic light',
#     'backpack',
#     'person',
#     'car',
#     'handbag']},
#   242457: {'file_name': 'COCO_train2014_000000242457.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'cell phone']},
#   367477: {'file_name': 'COCO_train2014_000000367477.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person']},
#   298906: {'file_name': 'COCO_train2014_000000298906.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'car', 'truck']},
#   147091: {'file_name': 'COCO_train2014_000000147091.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person']},
#   155302: {'file_name': 'COCO_train2014_000000155302.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person']},
#   306800: {'file_name': 'COCO_train2014_000000306800.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['bottle', 'chair', 'person', 'fire hydrant']},
#   424368: {'file_name': 'COCO_train2014_000000424368.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'cell phone', 'backpack', 'handbag']},
#   502894: {'file_name': 'COCO_train2014_000000502894.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['dog', 'person', 'backpack', 'suitcase', 'handbag']},
#   218546: {'file_name': 'COCO_train2014_000000218546.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person', 'truck', 'bench']},
#   560943: {'file_name': 'COCO_train2014_000000560943.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle',
#     'person',
#     'stop sign',
#     'handbag',
#     'potted plant',
#     'car']},
#   478532: {'file_name': 'COCO_train2014_000000478532.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car',
#     'person',
#     'traffic light',
#     'backpack',
#     'handbag',
#     'bus',
#     'parking meter',
#     'train']},
#   206912: {'file_name': 'COCO_train2014_000000206912.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'suitcase']},
#   511279: {'file_name': 'COCO_train2014_000000511279.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car',
#     'person',
#     'handbag',
#     'suitcase',
#     'parking meter',
#     'backpack',
#     'traffic light']},
#   400822: {'file_name': 'COCO_train2014_000000400822.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['skateboard', 'handbag', 'person']},
#   120541: {'file_name': 'COCO_train2014_000000120541.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['skateboard', 'backpack', 'person', 'handbag']},
#   491743: {'file_name': 'COCO_train2014_000000491743.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'cell phone']},
#   59843: {'file_name': 'COCO_train2014_000000059843.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['cell phone', 'handbag', 'person']},
#   152769: {'file_name': 'COCO_train2014_000000152769.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['bottle',
#     'person',
#     'car',
#     'cup',
#     'fork',
#     'knife',
#     'bowl',
#     'orange',
#     'dining table']},
#   12933: {'file_name': 'COCO_train2014_000000012933.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'umbrella', 'motorcycle']},
#   18171: {'file_name': 'COCO_train2014_000000018171.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'parking meter', 'backpack']},
#   266311: {'file_name': 'COCO_train2014_000000266311.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard', 'boat']},
#   523487: {'file_name': 'COCO_train2014_000000523487.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'cell phone', 'backpack']},
#   461226: {'file_name': 'COCO_train2014_000000461226.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'truck', 'traffic light']},
#   194336: {'file_name': 'COCO_train2014_000000194336.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'fire hydrant', 'stop sign']},
#   84981: {'file_name': 'COCO_train2014_000000084981.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['train', 'person', 'backpack']},
#   99135: {'file_name': 'COCO_train2014_000000099135.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'elephant', 'banana']},
#   5073: {'file_name': 'COCO_train2014_000000005073.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'truck', 'person', 'skateboard', 'bench']},
#   72156: {'file_name': 'COCO_train2014_000000072156.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['skateboard',
#     'backpack',
#     'truck',
#     'person',
#     'potted plant']},
#   314067: {'file_name': 'COCO_train2014_000000314067.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['cell phone', 'person']},
#   580238: {'file_name': 'COCO_train2014_000000580238.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'bench']},
#   477459: {'file_name': 'COCO_train2014_000000477459.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person', 'book']},
#   498218: {'file_name': 'COCO_train2014_000000498218.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'motorcycle']},
#   461496: {'file_name': 'COCO_train2014_000000461496.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['bus', 'backpack', 'handbag', 'person']},
#   371360: {'file_name': 'COCO_train2014_000000371360.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['stop sign', 'person']},
#   56048: {'file_name': 'COCO_train2014_000000056048.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'backpack', 'person', 'handbag']},
#   463168: {'file_name': 'COCO_train2014_000000463168.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'umbrella', 'handbag']},
#   531998: {'file_name': 'COCO_train2014_000000531998.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'bench', 'skateboard', 'backpack']},
#   26304: {'file_name': 'COCO_train2014_000000026304.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'cell phone', 'backpack', 'handbag']},
#   530037: {'file_name': 'COCO_train2014_000000530037.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['suitcase', 'person']},
#   210363: {'file_name': 'COCO_train2014_000000210363.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard', 'cell phone', 'bench']},
#   403489: {'file_name': 'COCO_train2014_000000403489.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['cell phone',
#     'car',
#     'person',
#     'stop sign',
#     'handbag',
#     'truck']},
#   84183: {'file_name': 'COCO_train2014_000000084183.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['cell phone',
#     'backpack',
#     'person',
#     'car',
#     'bus',
#     'traffic light',
#     'handbag',
#     'truck']},
#   390879: {'file_name': 'COCO_train2014_000000390879.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'bench', 'handbag', 'cell phone']},
#   244293: {'file_name': 'COCO_train2014_000000244293.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['horse',
#     'car',
#     'person',
#     'traffic light',
#     'truck',
#     'backpack']},
#   292519: {'file_name': 'COCO_train2014_000000292519.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person']},
#   577556: {'file_name': 'COCO_train2014_000000577556.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'tie', 'cake', 'knife']},
#   193878: {'file_name': 'COCO_train2014_000000193878.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['dog', 'person', 'handbag']},
#   306219: {'file_name': 'COCO_train2014_000000306219.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['dog', 'bus', 'person', 'traffic light']},
#   275206: {'file_name': 'COCO_train2014_000000275206.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'bus', 'person', 'traffic light', 'train']},
#   182801: {'file_name': 'COCO_train2014_000000182801.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car',
#     'person',
#     'traffic light',
#     'umbrella',
#     'backpack']},
#   297011: {'file_name': 'COCO_train2014_000000297011.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'umbrella', 'handbag']},
#   125822: {'file_name': 'COCO_train2014_000000125822.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard']},
#   389244: {'file_name': 'COCO_train2014_000000389244.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person', 'skateboard', 'potted plant']},
#   511346: {'file_name': 'COCO_train2014_000000511346.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard']},
#   394583: {'file_name': 'COCO_train2014_000000394583.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['cell phone', 'backpack', 'person', 'handbag']},
#   316446: {'file_name': 'COCO_train2014_000000316446.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['cell phone', 'person']},
#   123935: {'file_name': 'COCO_train2014_000000123935.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['bus', 'person', 'bench', 'backpack', 'bottle']},
#   492131: {'file_name': 'COCO_train2014_000000492131.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'motorcycle', 'person', 'truck']},
#   238231: {'file_name': 'COCO_train2014_000000238231.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person', 'dog']},
#   158915: {'file_name': 'COCO_train2014_000000158915.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['bus', 'person', 'traffic light', 'car']},
#   171766: {'file_name': 'COCO_train2014_000000171766.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'traffic light', 'backpack', 'car']},
#   295655: {'file_name': 'COCO_train2014_000000295655.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'cell phone', 'handbag', 'car']},
#   73437: {'file_name': 'COCO_train2014_000000073437.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['potted plant', 'person', 'backpack', 'bench']},
#   36482: {'file_name': 'COCO_train2014_000000036482.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['tv', 'person', 'book']},
#   8794: {'file_name': 'COCO_train2014_000000008794.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'tie']},
#   400107: {'file_name': 'COCO_train2014_000000400107.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'tie']},
#   394547: {'file_name': 'COCO_train2014_000000394547.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'umbrella']},
#   31465: {'file_name': 'COCO_train2014_000000031465.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['skateboard', 'person', 'backpack', 'handbag']},
#   135270: {'file_name': 'COCO_train2014_000000135270.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'skateboard', 'handbag', 'truck']},
#   249139: {'file_name': 'COCO_train2014_000000249139.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'sports ball', 'tennis racket']},
#   423776: {'file_name': 'COCO_train2014_000000423776.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['potted plant', 'person']},
#   28099: {'file_name': 'COCO_train2014_000000028099.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person']},
#   552198: {'file_name': 'COCO_train2014_000000552198.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person']},
#   392606: {'file_name': 'COCO_train2014_000000392606.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'bus', 'person', 'traffic light']},
#   336181: {'file_name': 'COCO_train2014_000000336181.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'motorcycle', 'handbag']},
#   121869: {'file_name': 'COCO_train2014_000000121869.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['cow', 'car', 'person']},
#   409216: {'file_name': 'COCO_train2014_000000409216.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['suitcase', 'person', 'cup']},
#   313502: {'file_name': 'COCO_train2014_000000313502.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard']},
#   538523: {'file_name': 'COCO_train2014_000000538523.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard', 'bottle', 'car']},
#   73262: {'file_name': 'COCO_train2014_000000073262.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'bench', 'skateboard']},
#   97724: {'file_name': 'COCO_train2014_000000097724.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard']},
#   150559: {'file_name': 'COCO_train2014_000000150559.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['cell phone', 'car', 'person', 'truck', 'handbag']},
#   292120: {'file_name': 'COCO_train2014_000000292120.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'tie', 'scissors', 'potted plant']},
#   61982: {'file_name': 'COCO_train2014_000000061982.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'bench']},
#   494534: {'file_name': 'COCO_train2014_000000494534.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'bottle', 'cup', 'bowl']},
#   152328: {'file_name': 'COCO_train2014_000000152328.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'handbag']},
#   4331: {'file_name': 'COCO_train2014_000000004331.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['bus', 'person', 'backpack']},
#   146091: {'file_name': 'COCO_train2014_000000146091.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'stop sign', 'handbag']},
#   7524: {'file_name': 'COCO_train2014_000000007524.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['horse',
#     'motorcycle',
#     'bus',
#     'traffic light',
#     'person',
#     'handbag',
#     'backpack']},
#   155806: {'file_name': 'COCO_train2014_000000155806.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'motorcycle']},
#   220006: {'file_name': 'COCO_train2014_000000220006.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['cow', 'person']},
#   271814: {'file_name': 'COCO_train2014_000000271814.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person',
#     'motorcycle',
#     'umbrella',
#     'handbag',
#     'refrigerator']},
#   439801: {'file_name': 'COCO_train2014_000000439801.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['cell phone', 'person', 'cup', 'chair', 'potted plant']},
#   353288: {'file_name': 'COCO_train2014_000000353288.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'clock', 'handbag', 'suitcase']},
#   121929: {'file_name': 'COCO_train2014_000000121929.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'traffic light', 'backpack', 'stop sign']},
#   185177: {'file_name': 'COCO_train2014_000000185177.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'suitcase', 'car']},
#   178040: {'file_name': 'COCO_train2014_000000178040.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'bench', 'backpack', 'potted plant']},
#   164659: {'file_name': 'COCO_train2014_000000164659.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['dog', 'person', 'handbag']},
#   181837: {'file_name': 'COCO_train2014_000000181837.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'bench']},
#   143538: {'file_name': 'COCO_train2014_000000143538.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person']},
#   577358: {'file_name': 'COCO_train2014_000000577358.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['bottle', 'person', 'backpack', 'handbag']},
#   3988: {'file_name': 'COCO_train2014_000000003988.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car',
#     'bus',
#     'person',
#     'truck',
#     'traffic light',
#     'cell phone',
#     'handbag']},
#   276768: {'file_name': 'COCO_train2014_000000276768.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['bus', 'person', 'handbag', 'car']},
#   462833: {'file_name': 'COCO_train2014_000000462833.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['train', 'person']},
#   68176: {'file_name': 'COCO_train2014_000000068176.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'truck', 'traffic light', 'person']},
#   24259: {'file_name': 'COCO_train2014_000000024259.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'traffic light', 'person', 'truck']},
#   285149: {'file_name': 'COCO_train2014_000000285149.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'motorcycle', 'person']},
#   253054: {'file_name': 'COCO_train2014_000000253054.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'motorcycle', 'bus', 'person', 'truck']},
#   320566: {'file_name': 'COCO_train2014_000000320566.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle',
#     'bus',
#     'truck',
#     'person',
#     'traffic light',
#     'handbag']},
#   338549: {'file_name': 'COCO_train2014_000000338549.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['horse', 'car', 'bus', 'person', 'traffic light']},
#   24621: {'file_name': 'COCO_train2014_000000024621.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard']},
#   241342: {'file_name': 'COCO_train2014_000000241342.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'skateboard']},
#   257928: {'file_name': 'COCO_train2014_000000257928.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['tv', 'couch', 'person', 'remote', 'book', 'chair']},
#   114540: {'file_name': 'COCO_train2014_000000114540.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['boat', 'handbag', 'suitcase', 'person']},
#   520750: {'file_name': 'COCO_train2014_000000520750.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'handbag', 'motorcycle']},
#   40286: {'file_name': 'COCO_train2014_000000040286.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'motorcycle', 'person', 'backpack']},
#   58296: {'file_name': 'COCO_train2014_000000058296.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person']},
#   497216: {'file_name': 'COCO_train2014_000000497216.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'umbrella', 'frisbee']},
#   36273: {'file_name': 'COCO_train2014_000000036273.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'frisbee', 'car']},
#   286870: {'file_name': 'COCO_train2014_000000286870.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'car', 'frisbee']},
#   364691: {'file_name': 'COCO_train2014_000000364691.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['skateboard', 'person']},
#   289693: {'file_name': 'COCO_train2014_000000289693.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['umbrella',
#     'chair',
#     'person',
#     'skateboard',
#     'backpack',
#     'handbag']},
#   62761: {'file_name': 'COCO_train2014_000000062761.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['skateboard', 'person']},
#   374418: {'file_name': 'COCO_train2014_000000374418.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['skateboard', 'person', 'handbag']},
#   81443: {'file_name': 'COCO_train2014_000000081443.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard']},
#   290403: {'file_name': 'COCO_train2014_000000290403.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person', 'skateboard']},
#   25996: {'file_name': 'COCO_train2014_000000025996.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'skateboard', 'person']},
#   26488: {'file_name': 'COCO_train2014_000000026488.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['bird', 'bus', 'person', 'bench']},
#   350960: {'file_name': 'COCO_train2014_000000350960.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person',
#     'refrigerator',
#     'microwave',
#     'oven',
#     'cup',
#     'bowl',
#     'orange',
#     'sink']},
#   309526: {'file_name': 'COCO_train2014_000000309526.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['dog', 'person']},
#   92710: {'file_name': 'COCO_train2014_000000092710.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'dog', 'handbag']},
#   502679: {'file_name': 'COCO_train2014_000000502679.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'surfboard', 'boat']},
#   580191: {'file_name': 'COCO_train2014_000000580191.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'umbrella', 'person', 'banana']},
#   255495: {'file_name': 'COCO_train2014_000000255495.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['traffic light', 'car', 'person']},
#   251974: {'file_name': 'COCO_train2014_000000251974.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'backpack', 'cup', 'bus']},
#   164076: {'file_name': 'COCO_train2014_000000164076.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['bus', 'person', 'traffic light']},
#   84499: {'file_name': 'COCO_train2014_000000084499.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['bus', 'person', 'truck', 'cow']},
#   516590: {'file_name': 'COCO_train2014_000000516590.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'umbrella', 'backpack']},
#   300537: {'file_name': 'COCO_train2014_000000300537.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['umbrella', 'car', 'person', 'backpack', 'fire hydrant']},
#   266153: {'file_name': 'COCO_train2014_000000266153.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car',
#     'person',
#     'bench',
#     'frisbee',
#     'backpack',
#     'umbrella']},
#   438864: {'file_name': 'COCO_train2014_000000438864.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard']},
#   537152: {'file_name': 'COCO_train2014_000000537152.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['umbrella', 'skateboard', 'person', 'handbag']},
#   523576: {'file_name': 'COCO_train2014_000000523576.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'umbrella', 'skateboard', 'chair']},
#   28654: {'file_name': 'COCO_train2014_000000028654.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'skateboard']},
#   127298: {'file_name': 'COCO_train2014_000000127298.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'kite']},
#   410680: {'file_name': 'COCO_train2014_000000410680.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['train', 'person', 'backpack']},
#   104800: {'file_name': 'COCO_train2014_000000104800.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'bus', 'handbag', 'dog', 'backpack']},
#   296901: {'file_name': 'COCO_train2014_000000296901.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['bus',
#     'traffic light',
#     'backpack',
#     'person',
#     'tv',
#     'handbag']},
#   420859: {'file_name': 'COCO_train2014_000000420859.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person']},
#   294379: {'file_name': 'COCO_train2014_000000294379.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person']},
#   244713: {'file_name': 'COCO_train2014_000000244713.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'potted plant']},
#   262967: {'file_name': 'COCO_train2014_000000262967.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'motorcycle', 'person', 'handbag', 'truck']},
#   128137: {'file_name': 'COCO_train2014_000000128137.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person', 'car']},
#   484650: {'file_name': 'COCO_train2014_000000484650.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['bus', 'person', 'handbag']},
#   29639: {'file_name': 'COCO_train2014_000000029639.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'truck', 'person', 'bottle', 'chair']},
#   549183: {'file_name': 'COCO_train2014_000000549183.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'umbrella', 'handbag', 'backpack']},
#   325390: {'file_name': 'COCO_train2014_000000325390.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['chair',
#     'person',
#     'umbrella',
#     'banana',
#     'donut',
#     'cake']},
#   353086: {'file_name': 'COCO_train2014_000000353086.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person']},
#   165046: {'file_name': 'COCO_train2014_000000165046.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person']},
#   186205: {'file_name': 'COCO_train2014_000000186205.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'cell phone']},
#   181367: {'file_name': 'COCO_train2014_000000181367.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'bench']},
#   58143: {'file_name': 'COCO_train2014_000000058143.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['train', 'person', 'handbag']},
#   350703: {'file_name': 'COCO_train2014_000000350703.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['traffic light', 'person', 'truck', 'car']},
#   262508: {'file_name': 'COCO_train2014_000000262508.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'baseball glove']},
#   351439: {'file_name': 'COCO_train2014_000000351439.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'tie', 'skateboard', 'handbag', 'backpack']},
#   244095: {'file_name': 'COCO_train2014_000000244095.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard']},
#   537673: {'file_name': 'COCO_train2014_000000537673.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard']},
#   282415: {'file_name': 'COCO_train2014_000000282415.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person',
#     'traffic light',
#     'backpack',
#     'handbag',
#     'truck',
#     'tv']},
#   84585: {'file_name': 'COCO_train2014_000000084585.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'tie']},
#   382316: {'file_name': 'COCO_train2014_000000382316.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'umbrella', 'handbag']},
#   29241: {'file_name': 'COCO_train2014_000000029241.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'handbag', 'cell phone']},
#   272901: {'file_name': 'COCO_train2014_000000272901.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car',
#     'person',
#     'truck',
#     'backpack',
#     'parking meter',
#     'handbag',
#     'traffic light']},
#   504021: {'file_name': 'COCO_train2014_000000504021.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'bus', 'person', 'traffic light']},
#   28231: {'file_name': 'COCO_train2014_000000028231.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'potted plant']},
#   449760: {'file_name': 'COCO_train2014_000000449760.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'car', 'bus']},
#   232339: {'file_name': 'COCO_train2014_000000232339.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'motorcycle', 'person', 'backpack', 'truck']},
#   451793: {'file_name': 'COCO_train2014_000000451793.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['bus', 'person', 'car', 'handbag']},
#   428142: {'file_name': 'COCO_train2014_000000428142.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['handbag', 'suitcase', 'person', 'backpack']},
#   259535: {'file_name': 'COCO_train2014_000000259535.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'frisbee', 'boat']},
#   317162: {'file_name': 'COCO_train2014_000000317162.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['cat', 'person']},
#   163571: {'file_name': 'COCO_train2014_000000163571.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['dog', 'car', 'person']},
#   195463: {'file_name': 'COCO_train2014_000000195463.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['dog', 'car', 'motorcycle', 'person', 'backpack']},
#   575589: {'file_name': 'COCO_train2014_000000575589.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person']},
#   61730: {'file_name': 'COCO_train2014_000000061730.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['dog', 'motorcycle', 'bench', 'person']},
#   551438: {'file_name': 'COCO_train2014_000000551438.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard', 'bench']},
#   151778: {'file_name': 'COCO_train2014_000000151778.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person']},
#   474067: {'file_name': 'COCO_train2014_000000474067.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person']},
#   232329: {'file_name': 'COCO_train2014_000000232329.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person']},
#   498730: {'file_name': 'COCO_train2014_000000498730.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['umbrella', 'car', 'person', 'handbag', 'parking meter']},
#   574964: {'file_name': 'COCO_train2014_000000574964.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard', 'truck']},
#   366040: {'file_name': 'COCO_train2014_000000366040.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['potted plant', 'chair', 'person', 'pizza']},
#   437485: {'file_name': 'COCO_train2014_000000437485.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['bottle',
#     'person',
#     'cell phone',
#     'cup',
#     'book',
#     'handbag',
#     'chair']},
#   363389: {'file_name': 'COCO_train2014_000000363389.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'handbag', 'refrigerator']},
#   113521: {'file_name': 'COCO_train2014_000000113521.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'motorcycle', 'bench']},
#   325042: {'file_name': 'COCO_train2014_000000325042.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['dog', 'person', 'truck']},
#   317911: {'file_name': 'COCO_train2014_000000317911.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person', 'truck']},
#   464303: {'file_name': 'COCO_train2014_000000464303.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['bottle', 'person', 'cell phone', 'backpack']},
#   406420: {'file_name': 'COCO_train2014_000000406420.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['bottle', 'chair', 'person', 'bench', 'cup']},
#   394501: {'file_name': 'COCO_train2014_000000394501.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'traffic light']},
#   121731: {'file_name': 'COCO_train2014_000000121731.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['cow', 'person', 'sheep', 'umbrella']},
#   464856: {'file_name': 'COCO_train2014_000000464856.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['tie', 'cell phone', 'car', 'person', 'handbag']},
# ...
#   136070: {'file_name': 'COCO_train2014_000000136070.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'bench', 'backpack', 'cell phone']},
#   423739: {'file_name': 'COCO_train2014_000000423739.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'cell phone', 'bench', 'backpack']},
#   258552: {'file_name': 'COCO_train2014_000000258552.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'truck', 'traffic light', 'car']},
#   265990: {'file_name': 'COCO_train2014_000000265990.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'umbrella']},
#   318807: {'file_name': 'COCO_train2014_000000318807.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard']},
#   407596: {'file_name': 'COCO_train2014_000000407596.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'sports ball']},
#   537289: {'file_name': 'COCO_train2014_000000537289.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['bed', 'person', 'backpack', 'tie', 'chair', 'car']},
#   522423: {'file_name': 'COCO_train2014_000000522423.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'bottle', 'chair']},
#   96457: {'file_name': 'COCO_train2014_000000096457.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person']},
#   438081: {'file_name': 'COCO_train2014_000000438081.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person']},
#   69052: {'file_name': 'COCO_train2014_000000069052.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'bottle', 'backpack']},
#   84277: {'file_name': 'COCO_train2014_000000084277.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'motorcycle', 'person', 'backpack', 'apple']},
#   162355: {'file_name': 'COCO_train2014_000000162355.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['cow', 'bus', 'person']},
#   373212: {'file_name': 'COCO_train2014_000000373212.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person']},
#   166631: {'file_name': 'COCO_train2014_000000166631.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'elephant', 'backpack', 'truck']},
#   342666: {'file_name': 'COCO_train2014_000000342666.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['skateboard', 'person', 'handbag', 'tie']},
#   360396: {'file_name': 'COCO_train2014_000000360396.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'donut']},
#   30395: {'file_name': 'COCO_train2014_000000030395.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'stop sign', 'kite']},
#   267927: {'file_name': 'COCO_train2014_000000267927.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'bus', 'person', 'traffic light']},
#   90359: {'file_name': 'COCO_train2014_000000090359.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['dog', 'person', 'bench', 'handbag', 'boat']},
#   274409: {'file_name': 'COCO_train2014_000000274409.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'bench']},
#   433910: {'file_name': 'COCO_train2014_000000433910.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'book']},
#   437643: {'file_name': 'COCO_train2014_000000437643.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person']},
#   536145: {'file_name': 'COCO_train2014_000000536145.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['bus', 'traffic light', 'person']},
#   344040: {'file_name': 'COCO_train2014_000000344040.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['chair',
#     'airplane',
#     'person',
#     'potted plant',
#     'backpack']},
#   176440: {'file_name': 'COCO_train2014_000000176440.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'fire hydrant']},
#   437522: {'file_name': 'COCO_train2014_000000437522.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'traffic light', 'fire hydrant']},
#   108566: {'file_name': 'COCO_train2014_000000108566.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['umbrella', 'person']},
#   107862: {'file_name': 'COCO_train2014_000000107862.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['dog', 'person', 'baseball bat', 'baseball glove']},
#   200423: {'file_name': 'COCO_train2014_000000200423.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard']},
#   286492: {'file_name': 'COCO_train2014_000000286492.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard']},
#   238808: {'file_name': 'COCO_train2014_000000238808.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'stop sign', 'potted plant', 'car']},
#   99129: {'file_name': 'COCO_train2014_000000099129.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['bus', 'person', 'motorcycle', 'car']},
#   81188: {'file_name': 'COCO_train2014_000000081188.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['umbrella', 'backpack', 'handbag', 'suitcase', 'person']},
#   16123: {'file_name': 'COCO_train2014_000000016123.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'banana', 'apple']},
#   442518: {'file_name': 'COCO_train2014_000000442518.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'sports ball', 'baseball glove', 'car']},
#   146645: {'file_name': 'COCO_train2014_000000146645.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['bottle', 'person', 'banana']},
#   49796: {'file_name': 'COCO_train2014_000000049796.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['umbrella', 'person', 'kite', 'bench', 'handbag']},
#   430898: {'file_name': 'COCO_train2014_000000430898.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'kite', 'traffic light', 'backpack']},
#   154898: {'file_name': 'COCO_train2014_000000154898.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'truck', 'baseball bat']},
#   492020: {'file_name': 'COCO_train2014_000000492020.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'tie', 'handbag']},
#   549639: {'file_name': 'COCO_train2014_000000549639.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'car', 'surfboard']},
#   465813: {'file_name': 'COCO_train2014_000000465813.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'truck', 'traffic light', 'backpack']},
#   392363: {'file_name': 'COCO_train2014_000000392363.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'car', 'motorcycle']},
#   126686: {'file_name': 'COCO_train2014_000000126686.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person']},
#   551647: {'file_name': 'COCO_train2014_000000551647.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'motorcycle', 'person', 'traffic light']},
#   48759: {'file_name': 'COCO_train2014_000000048759.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['bus',
#     'person',
#     'stop sign',
#     'traffic light',
#     'car',
#     'train',
#     'handbag']},
#   16216: {'file_name': 'COCO_train2014_000000016216.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'umbrella', 'backpack']},
#   142418: {'file_name': 'COCO_train2014_000000142418.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'skateboard', 'backpack']},
#   540206: {'file_name': 'COCO_train2014_000000540206.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'bench', 'frisbee']},
#   327258: {'file_name': 'COCO_train2014_000000327258.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['horse', 'person', 'bus', 'car']},
#   189598: {'file_name': 'COCO_train2014_000000189598.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'skateboard']},
#   548822: {'file_name': 'COCO_train2014_000000548822.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['sports ball', 'person', 'bench']},
#   27041: {'file_name': 'COCO_train2014_000000027041.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['chair',
#     'car',
#     'person',
#     'umbrella',
#     'laptop',
#     'backpack',
#     'suitcase']},
#   226825: {'file_name': 'COCO_train2014_000000226825.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['chair', 'car', 'motorcycle', 'person', 'dining table']},
#   41459: {'file_name': 'COCO_train2014_000000041459.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'car', 'backpack', 'handbag', 'traffic light']},
#   147331: {'file_name': 'COCO_train2014_000000147331.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['potted plant', 'car', 'person', 'book']},
#   312286: {'file_name': 'COCO_train2014_000000312286.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car',
#     'umbrella',
#     'handbag',
#     'truck',
#     'person',
#     'backpack']},
#   213506: {'file_name': 'COCO_train2014_000000213506.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person', 'handbag']},
#   204279: {'file_name': 'COCO_train2014_000000204279.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'traffic light', 'handbag']},
#   495310: {'file_name': 'COCO_train2014_000000495310.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'car', 'truck', 'traffic light']},
#   242458: {'file_name': 'COCO_train2014_000000242458.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person']},
#   362282: {'file_name': 'COCO_train2014_000000362282.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['umbrella', 'person', 'backpack', 'handbag', 'chair']},
#   267205: {'file_name': 'COCO_train2014_000000267205.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['motorcycle', 'person', 'umbrella']},
#   189831: {'file_name': 'COCO_train2014_000000189831.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'cell phone']},
#   6692: {'file_name': 'COCO_train2014_000000006692.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'tie']},
#   58926: {'file_name': 'COCO_train2014_000000058926.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'motorcycle']},
#   116725: {'file_name': 'COCO_train2014_000000116725.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'surfboard', 'backpack']},
#   197368: {'file_name': 'COCO_train2014_000000197368.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'tie']},
#   575280: {'file_name': 'COCO_train2014_000000575280.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'surfboard', 'boat']},
#   76740: {'file_name': 'COCO_train2014_000000076740.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'sports ball', 'tennis racket']},
#   486178: {'file_name': 'COCO_train2014_000000486178.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'cell phone', 'book']},
#   170506: {'file_name': 'COCO_train2014_000000170506.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'truck', 'handbag']},
#   246056: {'file_name': 'COCO_train2014_000000246056.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['person', 'handbag']},
#   365573: {'file_name': 'COCO_train2014_000000365573.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'bench', 'backpack', 'bottle']},
#   34551: {'file_name': 'COCO_train2014_000000034551.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['umbrella', 'person', 'handbag']},
#   465047: {'file_name': 'COCO_train2014_000000465047.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['bus', 'person', 'backpack']},
#   351968: {'file_name': 'COCO_train2014_000000351968.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'handbag', 'tv', 'backpack', 'skis']},
#   494174: {'file_name': 'COCO_train2014_000000494174.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'surfboard']},
#   31813: {'file_name': 'COCO_train2014_000000031813.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'surfboard', 'truck']},
#   83580: {'file_name': 'COCO_train2014_000000083580.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'surfboard', 'car', 'truck']},
#   67269: {'file_name': 'COCO_train2014_000000067269.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'surfboard']},
#   461458: {'file_name': 'COCO_train2014_000000461458.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'backpack', 'clock']},
#   396853: {'file_name': 'COCO_train2014_000000396853.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'cell phone', 'handbag']},
#   372740: {'file_name': 'COCO_train2014_000000372740.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'handbag']},
#   150197: {'file_name': 'COCO_train2014_000000150197.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'backpack']},
#   16616: {'file_name': 'COCO_train2014_000000016616.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'backpack', 'truck', 'cell phone']},
#   308433: {'file_name': 'COCO_train2014_000000308433.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['bus', 'person', 'car']},
#   357549: {'file_name': 'COCO_train2014_000000357549.jpg',
#    'gender': 'female',
#    'target': 'bicycle',
#    'other_targets': ['train', 'person', 'handbag']},
#   539358: {'file_name': 'COCO_train2014_000000539358.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'train', 'person', 'stop sign']},
#   554891: {'file_name': 'COCO_train2014_000000554891.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'car', 'bench', 'cup', 'bowl']},
#   244353: {'file_name': 'COCO_train2014_000000244353.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'person', 'fire hydrant']},
#   191072: {'file_name': 'COCO_train2014_000000191072.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car', 'bus', 'person', 'backpack']},
#   126608: {'file_name': 'COCO_train2014_000000126608.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['car',
#     'person',
#     'traffic light',
#     'backpack',
#     'fire hydrant']},
#   535737: {'file_name': 'COCO_train2014_000000535737.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['stop sign', 'person', 'car', 'handbag']},
#   104588: {'file_name': 'COCO_train2014_000000104588.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'surfboard']},
#   515743: {'file_name': 'COCO_train2014_000000515743.jpg',
#    'gender': 'male',
#    'target': 'bicycle',
#    'other_targets': ['person', 'surfboard']}})

# %%
# Convert dictionary to json file 
with open('data.json', 'w') as fp:
    json.dump(target_img_dict, fp, indent=4)

# %% [markdown]
# # Filter targets not strongly relevant

# %%
# gather targets that have less than 100 images in the training set

while True:
    irrelevant_targets = []
    target_img_dict_items = target_img_dict.items()
    for category in categories:
        category_name = category["name"]
        if not (category_name in target_img_dict):
            continue
        #print("category: ", category_name, " number of images: ", len(target_img_dict[category_name]))
        if len(target_img_dict[category_name]) < 100:
            irrelevant_targets.append(category_name)
    if not irrelevant_targets:
        break

    print("irrelevant targets: ", irrelevant_targets)

    # remove irrelevant targets from target_img_dict
    images_to_remove = set()
    for target in irrelevant_targets:
        images_to_remove.update(list(target_img_dict[target].keys()))
        del target_img_dict[target]
    print("images to remove: ", images_to_remove)
    print("number of images to remove: ", len(images_to_remove))
    for target, image_dict in target_img_dict.items():
        for image_id in images_to_remove:
            if image_id in image_dict:
                #print("removing image: ", image_id, " from target: ", target)
                del image_dict[image_id]
# Out:
# irrelevant targets:  ['bear', 'zebra', 'broccoli', 'carrot', 'toaster', 'hair drier']
# images to remove:  {21504, 118785, 267266, 157186, 266756, 457734, 449032, 349709, 403982, 122382, 516624, 24081, 443410, 478227, 221717, 121366, 159768, 129563, 111646, 284703, 318497, 300578, 208931, 210471, 528938, 37931, 69675, 502827, 95278, 429614, 439346, 430643, 560691, 411189, 356916, 71224, 163385, 546361, 74820, 361547, 95308, 438349, 11856, 86611, 334423, 391258, 434270, 118369, 561763, 29799, 444010, 364139, 116334, 395888, 397938, 77426, 529524, 341621, 77432, 313465, 207481, 243327, 208000, 444033, 147073, 369283, 209027, 407173, 73864, 198793, 515210, 114316, 102550, 290967, 208022, 545944, 229530, 410779, 544408, 541343, 85666, 329380, 20136, 243373, 116911, 72370, 407734, 362166, 178872, 443579, 553660, 234685, 524476, 142016, 218305, 431817, 478410, 431820, 564729, 109774, 440527, 537293, 52433, 416978, 360147, 318677, 437464, 53464, 494811, 229084, 543454, 48863, 97504, 493792, 365282, 239331, 563935, 56550, 325863, 289514, 168173, 129262, 282357, 576247, 537335, 540922, 255226, 435456, 59648, 179968, 180997, 260359, 32522, 24842, 488203, 148240, 230673, 304125, 563477, 385302, 276247, 406296, 81177, 1307, 501022, 97057, 99619, 383267, 283942, 325416, 509225, 308520, 574760, 84268, 396082, 420146, 273716, 180020, 254775, 42808, 569143, 302903, 23355, 580408, 144705, 417090, 537924, 430405, 419145, 425807, 196944, 572756, 20311, 263512, 272729, 488792, 314204, 263516, 479068, 562014, 73568, 277857, 29538, 401766, 428391, 203112, 30569, 341865, 380780, 104304, 12661, 501110, 87933, 471936, 42371, 310665, 275339, 578449, 205202, 548755, 30100, 329623, 341399, 130458, 458650, 61852, 4508, 35741, 180639, 309152, 17312, 2466, 249764, 432037, 84391, 93612, 566188, 450478, 51630, 6572, 183218, 6578, 145845, 498614, 72118, 202168, 484281, 510399, 195525, 233926, 24520, 369610, 118736, 547797, 275413, 365015, 73174, 17883, 414684, 571867, 492510, 337883, 155105, 14818, 233955, 303076, 160741, 359909, 159723, 388075, 522225, 491505, 68594, 202739, 440822, 154616, 517625, 453629, 497662, 335871}
# number of images to remove:  260

# %%
def read_filtered_targets(file_path):
    target_list = []
    with open(file_path, 'r') as file:
        for line in file:
            target_list.append(line.strip().replace("_", " "))  # strip() removes leading/trailing whitespaces and newlines
    return target_list

filtered_targets = read_filtered_targets("filtered_targets.txt")
len(filtered_targets)
# Out:
# 66

# %%
category_names = [x["name"] for x in categories]
irrelevant_targets_MALS = list(set(category_names) - set(filtered_targets))
irrelevant_targets_MALS
# Out:
# ['orange',
#  'parking meter',
#  'bird',
#  'toaster',
#  'apple',
#  'scissors',
#  'bear',
#  'vase',
#  'sheep',
#  'carrot',
#  'hair drier',
#  'broccoli',
#  'stop sign',
#  'zebra']

# %%
weird_targets = [x for x in irrelevant_targets_MALS if x not in irrelevant_targets]
weird_targets
# Out:
# ['orange',
#  'parking meter',
#  'bird',
#  'toaster',
#  'apple',
#  'scissors',
#  'bear',
#  'vase',
#  'sheep',
#  'carrot',
#  'hair drier',
#  'broccoli',
#  'stop sign',
#  'zebra']

# %%
len(target_img_dict["vase"])
# Out:
# 283

# %%
[id for id, data in target_img_dict["vase"].items()]
# Out:
# [467809,
#  116268,
#  261479,
#  48711,
#  177858,
#  312247,
#  301631,
#  445965,
#  490099,
#  571799,
#  296153,
#  31536,
#  387045,
#  334364,
#  557527,
#  567268,
#  276200,
#  56608,
#  52634,
#  172506,
#  252069,
#  41319,
#  221840,
#  350044,
#  55276,
#  272741,
#  347403,
#  374239,
#  258414,
#  416878,
#  151566,
#  244597,
#  171139,
#  352357,
#  444409,
#  275982,
#  24175,
#  464766,
#  201273,
#  146972,
#  578866,
#  387087,
#  198607,
#  355638,
#  342340,
#  56287,
#  509442,
#  189750,
#  496942,
#  34795,
#  575938,
#  19994,
#  105529,
#  449913,
#  421108,
#  212311,
#  446064,
#  2083,
#  330164,
#  465123,
#  456035,
#  361437,
#  298034,
#  464810,
#  355440,
#  523997,
#  175101,
#  221663,
#  233319,
#  350940,
#  362768,
#  482728,
#  304385,
#  259067,
#  267216,
#  297724,
#  97130,
#  309840,
#  90962,
#  289075,
#  252093,
#  529676,
#  152036,
#  20421,
#  503557,
#  161749,
#  347016,
#  180351,
#  571603,
#  555586,
#  260957,
#  538537,
#  158501,
#  297995,
#  432604,
#  106123,
#  398301,
#  87101,
#  282733,
#  38718,
#  551169,
#  249455,
#  551522,
#  80911,
#  158362,
#  256190,
#  358421,
#  580026,
#  72792,
#  306439,
#  362879,
#  13106,
#  185818,
#  302415,
#  365934,
#  24436,
#  64619,
#  362199,
#  164093,
#  270024,
#  390125,
#  134510,
#  291915,
#  530851,
#  547837,
#  34039,
#  245209,
#  266715,
#  240101,
#  464150,
#  393306,
#  475488,
#  259228,
#  310258,
#  320929,
#  424044,
#  144246,
#  23311,
#  329386,
#  259595,
#  67462,
#  404899,
#  510246,
#  533316,
#  542213,
#  238316,
#  170008,
#  324504,
#  198426,
#  258975,
#  534000,
#  373522,
#  552461,
#  442150,
#  515710,
#  24939,
#  60350,
#  480161,
#  212787,
#  32739,
#  267048,
#  27792,
#  414887,
#  54692,
#  232670,
#  45859,
#  558910,
#  332540,
#  421759,
#  556544,
#  485350,
#  151954,
#  47502,
#  368474,
#  273863,
#  189345,
#  513532,
#  95753,
#  151403,
#  102029,
#  292597,
#  492065,
#  100386,
#  230061,
#  536760,
#  510859,
#  342618,
#  398124,
#  469914,
#  516655,
#  354389,
#  273383,
#  326723,
#  376988,
#  412281,
#  144467,
#  284195,
#  116064,
#  120320,
#  121613,
#  577725,
#  343570,
#  355050,
#  121046,
#  278230,
#  106836,
#  152815,
#  421876,
#  3915,
#  478845,
#  117184,
#  353790,
#  416549,
#  131580,
#  421840,
#  138961,
#  250350,
#  319907,
#  166233,
#  297157,
#  333748,
#  289662,
#  26995,
#  197525,
#  146481,
#  33761,
#  148208,
#  248417,
#  164290,
#  471686,
#  308399,
#  464443,
#  90251,
#  329543,
#  94260,
#  481402,
#  159953,
#  450455,
#  147054,
#  516300,
#  308606,
#  262407,
#  148938,
#  481689,
#  211388,
#  310457,
#  55823,
#  504258,
#  171103,
#  345225,
#  120400,
#  159808,
#  160810,
#  462819,
#  465595,
#  205931,
#  143532,
#  103383,
#  306703,
#  16273,
#  264005,
#  502670,
#  251111,
#  325089,
#  41729,
#  128608,
#  562830,
#  475668,
#  439576,
#  283615,
#  9651,
#  558142,
#  544294,
#  463284,
#  388961,
#  361619,
#  538424,
#  540723,
#  101450,
#  213214,
#  296477,
#  201738,
#  233642]

# %%
for img_id, img_data in target_img_dict["vase"].items():
    if not "person" in img_data["other_targets"]:
        print(img_id)
