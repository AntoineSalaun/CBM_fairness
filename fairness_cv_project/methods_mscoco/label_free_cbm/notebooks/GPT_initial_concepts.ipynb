# %%
import sys
from pathlib import Path
import os 
# sys.path.append('/home/gridsan/vyuan/.local/lib/python3.9/site-packages/')

current_path = Path.cwd()

# Go to top of the root and append
root = current_path.parents[3]
sys.path.append(str(root))

os.chdir(root)

# %%
import os
import json
from pathlib import Path

import openai

from fairness_cv_project.methods.label_free_cbm.src.utils import data_utils

# %%
dataset = "mscoco_single"
prompt_type = "important"

# %%
openai.api_key = open(os.path.join(os.path.expanduser("~"), ".openai_api_key"), "r").read()[:-1]

# %%
prompts = {
    "important" : "List the most important features for recognizing something as a \"goldfish\":\n\n-bright orange color\n-a small, round body\n-a long, flowing tail\n-a small mouth\n-orange fins\n\nList the most important features for recognizing something as a \"beerglass\":\n\n-a tall, cylindrical shape\n-clear or translucent color\n-opening at the top\n-a sturdy base\n-a handle\n\nList the most important features for recognizing something as a \"{}\":",
    "superclass" : "Give superclasses for the word \"tench\":\n\n-fish\n-vertebrate\n-animal\n\nGive superclasses for the word \"beer glass\":\n\n-glass\n-container\n-object\n\nGive superclasses for the word \"{}\":",
    "around" : "List the things most commonly seen around a \"tench\":\n\n- a pond\n-fish\n-a net\n-a rod\n-a reel\n-a hook\n-bait\n\nList the things most commonly seen around a \"beer glass\":\n\n- beer\n-a bar\n-a coaster\n-a napkin\n-a straw\n-a lime\n-a person\n\nList the things most commonly seen around a \"{}\":",
    "job": "List the things commonly seen around a \"teacher\":\n\n- a classroom\n-a desk\n-a chalkboard\n-a book\n-a student\n-a pencil\n-a pen\n\nList the things commonly seen around a \"software engineer\":\n\n- a computer\n-a desk\n-a keyboard\n-a mouse\n-a monitor\n-a chair\n-a person\n\nList the things commonly seen around someone's working as a \"{}\":",
}


base_prompt = prompts[prompt_type]

# %%
cls_file = data_utils.LABEL_FILES[dataset]
with open(root / cls_file, "r") as f:
    classes = f.read().split("\n")

# %%
classes
# Out:
# ['tennis racket',
#  'chair',
#  'cell phone',
#  'surfboard',
#  'bottle',
#  'skis',
#  'horse',
#  'bed',
#  'car',
#  'couch']

# %%
feature_dict = {}

for i, label in enumerate(classes):
    feature_dict[label] = set()
    print("\n", i, label)
    for _ in range(2):
        response = openai.Completion.create(
              model="text-davinci-002",
              prompt=base_prompt.format(label),
              temperature=0.7,
              max_tokens=256,
              top_p=1,
              frequency_penalty=0,
              presence_penalty=0
            )
        #clean up responses
        print(response)
        features = response["choices"][0]["text"]
        features = features.split("\n-")
        features = [feat.replace("\n", "") for feat in features]
        features = [feat.strip() for feat in features]
        features = [feat for feat in features if len(feat)>0]
        features = set(features)
        feature_dict[label].update(features)
    feature_dict[label] = sorted(list(feature_dict[label]))
# Out:
#  0 tennis racket
# {
#   "id": "cmpl-7hPlg517FSb7TnkXYj08tvdfaVZhk",
#   "object": "text_completion",
#   "created": 1690581512,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-a large, oval-shaped frame\n-a stringed grid across the middle\n-two handles on the sides\n-a small, round head",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 107,
#     "completion_tokens": 33,
#     "total_tokens": 140
#   }
# }
# {
#   "id": "cmpl-7hPlhvWwkbmH2xSYNdXAEF96vxu1Z",
#   "object": "text_completion",
#   "created": 1690581513,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-a large, oval-shaped frame\n-a network of strings stretched across the frame\n-a handle on one side\n-a small, round head on the other side",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 107,
#     "completion_tokens": 38,
#     "total_tokens": 145
#   }
# }
#
#  1 chair
# {
#   "id": "cmpl-7hPlhkkDFOFNDbXmvxJjlbXfJklM6",
#   "object": "text_completion",
#   "created": 1690581513,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-a seat for a person\n-a backrest\n-four legs\n-armrests (optional)",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 105,
#     "completion_tokens": 25,
#     "total_tokens": 130
#   }
# }
# {
#   "id": "cmpl-7hPliVKAuLystl8WwmgKsSRmCoRfA",
#   "object": "text_completion",
#   "created": 1690581514,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-a seat for a person\n-a backrest\n-four legs\n-armrests (optional)",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 105,
#     "completion_tokens": 25,
#     "total_tokens": 130
#   }
# }
#
#  2 cell phone
# {
#   "id": "cmpl-7hPljpWyvNXfOhpJD95eMccl8DVRx",
#   "object": "text_completion",
#   "created": 1690581515,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-a small, portable device\n-a display screen\n-a keyboard or touchscreen\n-one or more cameras\n-a microphone\n-a speaker",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 106,
#     "completion_tokens": 33,
#     "total_tokens": 139
#   }
# }
# {
#   "id": "cmpl-7hPljhOrK5B7zLyy5OF2Yt1j1La5K",
#   "object": "text_completion",
#   "created": 1690581515,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-a small, rectangular shape\n-a color screen\n-buttons or a touchscreen\n-a camera\n-a microphone",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 106,
#     "completion_tokens": 28,
#     "total_tokens": 134
#   }
# }
#
#  3 surfboard
# {
#   "id": "cmpl-7hPlkMqmX3KocmnN7VBsT6xK6uj02",
#   "object": "text_completion",
#   "created": 1690581516,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-a large, flat board\n-used for surfing\n-has a fin or multiple fins\n-can be different colors\n-can be different shapes and sizes",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 107,
#     "completion_tokens": 35,
#     "total_tokens": 142
#   }
# }
# {
#   "id": "cmpl-7hPllWqKKWRGdREfm7Y8JcdxaqXzE",
#   "object": "text_completion",
#   "created": 1690581517,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-a long, narrow shape\n-a pointed nose\n-a flat bottom\n-fins on the sides\n-decorations or graphics on the top",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 107,
#     "completion_tokens": 35,
#     "total_tokens": 142
#   }
# }
#
#  4 bottle
# {
#   "id": "cmpl-7hPlmSuywJRNgqQWEoiQFDWkEqyE7",
#   "object": "text_completion",
#   "created": 1690581518,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-a slender, cylindrical shape\n-a neck that is narrower than the body\n-a closed top\n-a label\n-a cap or cork",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 106,
#     "completion_tokens": 36,
#     "total_tokens": 142
#   }
# }
# {
#   "id": "cmpl-7hPlmP0h1co4cFHpmBjG0V0ztc4d7",
#   "object": "text_completion",
#   "created": 1690581518,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-a long, slender shape\n-a narrow neck\n-a screw-top or corked opening\n-usually made of glass or plastic\n-can be any size or color",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 106,
#     "completion_tokens": 40,
#     "total_tokens": 146
#   }
# }
#
#  5 skis
# {
#   "id": "cmpl-7hPlnXVFPxZ0saeZM0ejW8R3BbbLg",
#   "object": "text_completion",
#   "created": 1690581519,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-a long, narrow shape\n-a pointed end\n-a curved or V-shaped bottom\n-bindings for attaching to feet or boots\n-usually brightly colored",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 106,
#     "completion_tokens": 37,
#     "total_tokens": 143
#   }
# }
# {
#   "id": "cmpl-7hPlopFapc8TpASlFHO194f2Q5hku",
#   "object": "text_completion",
#   "created": 1690581520,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-a long, thin shape\n-a pointed end\n-a curved or V-shaped body\n-bindings for attaching to feet\n-used for sliding on snow",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 106,
#     "completion_tokens": 37,
#     "total_tokens": 143
#   }
# }
#
#  6 horse
# {
#   "id": "cmpl-7hPlpjVBYneixSfkS3dFp5XUAtLpt",
#   "object": "text_completion",
#   "created": 1690581521,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-a large body\n-four legs\n-a long neck\n-a tail\n-a mane",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 105,
#     "completion_tokens": 24,
#     "total_tokens": 129
#   }
# }
# {
#   "id": "cmpl-7hPlpvSHkVyl4HKAYzLY3obOhgI5h",
#   "object": "text_completion",
#   "created": 1690581521,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-a large body\n-four legs\n-a long neck\n-a tail\n-a mane",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 105,
#     "completion_tokens": 24,
#     "total_tokens": 129
#   }
# }
#
#  7 bed
# {
#   "id": "cmpl-7hPlqGXBC1yeEmEXrGLXEERNshyNw",
#   "object": "text_completion",
#   "created": 1690581522,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-a large, rectangular shape\n-a soft surface for sleeping\n-pillows and blankets\n-a headboard\n-a footboard",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 105,
#     "completion_tokens": 31,
#     "total_tokens": 136
#   }
# }
# {
#   "id": "cmpl-7hPlq5AfqtUhhYdJ14rAXHyUnQlBb",
#   "object": "text_completion",
#   "created": 1690581522,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-a large, flat surface\n-for sleeping on\n-usually has a frame\n-may have a headboard\n-may have a footboard\n-may have side rails\n-may have a mattress\n-may have sheets\n-may have a blanket\n-may have a pillow",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 105,
#     "completion_tokens": 62,
#     "total_tokens": 167
#   }
# }
#
#  8 car
# {
#   "id": "cmpl-7hPlsTNfDJuKlpLgT08jpNpkaqciO",
#   "object": "text_completion",
#   "created": 1690581524,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-four round, cylindrical shapes (wheels)\n-a long, rectangular body\n-windows along the sides\n-a door on the side\n-a steering wheel in the front",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 105,
#     "completion_tokens": 42,
#     "total_tokens": 147
#   }
# }
# {
#   "id": "cmpl-7hPltYZAAtzkNioQkXd3oxZNv0YSn",
#   "object": "text_completion",
#   "created": 1690581525,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-a large, rectangular body\n-four round, cylindrical shapes (wheels)\n-two headlights\n-a grille\n-a windshield\n-rearview mirrors",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 105,
#     "completion_tokens": 40,
#     "total_tokens": 145
#   }
# }
#
#  9 couch
# {
#   "id": "cmpl-7hPluKi1MpyP4FtLIxDv79e4PgcoG",
#   "object": "text_completion",
#   "created": 1690581526,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-a large, flat surface\n-a cushioned surface\n-three or more legs\n-armrests on either side",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 106,
#     "completion_tokens": 28,
#     "total_tokens": 134
#   }
# }
# {
#   "id": "cmpl-7hPluIDii7BGqY0HFOHFV7RAYS0tl",
#   "object": "text_completion",
#   "created": 1690581526,
#   "model": "text-davinci-002",
#   "choices": [
#     {
#       "text": "\n\n-a large, rectangular shape\n-a soft, padded surface\n-armrests on either side\n-a comfortable backrest",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 106,
#     "completion_tokens": 29,
#     "total_tokens": 135
#   }
# }

# %%
json_object = json.dumps(feature_dict, indent=4)
with open(root / "data/concept_sets/gpt3_init/gpt3_{}_{}_new.json".format(dataset, prompt_type), "w") as outfile:
    outfile.write(json_object)
